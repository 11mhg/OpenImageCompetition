# %%
from classifier_data.classifier_data import *
# Out:
# /home/mhg1/.local/lib/python3.5/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters

# %%
ppd = Data('./image_classifier/labels.txt')
classes = ppd.classes
print(classes)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-3-5c50fd4a4d9b> in <module>()
# ----> 1 ppd = Data('./image_classifier/labels.txt')
#       2 classes = ppd.classes
#       3 print(classes)
#
# ~/image_classifier/classifier_data/classifier_data.py in __init__(self, classes_text, image_size, batch_size, shuffle_buffer_size, prefetch_buffer_size, num_parallel_calls, num_parallel_readers)
#      10         with open(classes_text, 'r') as f:
#      11             self.classes = f.readlines()
# ---> 12         self.classes = [s.strip('\n').split(',')[1] for s in self.classes]
#      13         self.image_size = image_size
#      14         self.batch_size = batch_size
#
# ~/image_classifier/classifier_data/classifier_data.py in <listcomp>(.0)
#      10         with open(classes_text, 'r') as f:
#      11             self.classes = f.readlines()
# ...

# %%
dataset = ppd.get_batch('./Dataset/MOT/train_records/*.tfrecords')

# %%
print(dataset)
# Out:
# <PrefetchDataset shapes: ((?, 224, 224, 3), (?,)), types: (tf.float16, tf.int64)>

# %%
import tensorflow as tf
from tqdm import tqdm

# %%
iterator = dataset.make_initializable_iterator()
Image, Label = iterator.get_next()
print((Image,Label))
# Out:
# (<tf.Tensor 'IteratorGetNext_3:0' shape=(?, 224, 224, 3) dtype=float16>, <tf.Tensor 'IteratorGetNext_3:1' shape=(?,) dtype=int64>)

# %%
with tf.Session() as sess:
    sess.run(iterator.initializer)
    image, label = sess.run([Image,Label])

# %%
print(image.shape)
print(image.dtype)
# Out:
# (32, 224, 224, 3)
# float16

# %%
import PIL
index = np.random.randint(0,32)
image_1 = image[index,...].astype('uint8')
print(image_1.shape)
print(image_1.dtype)
# Out:
# (224, 224, 3)
# uint8

# %%
img = PIL.Image.fromarray(image_1)

# %%
img
# Out:
# <PIL.Image.Image image mode=RGB size=224x224 at 0x2B8AD6891A58>

# %%
classes[label[index]]
# Out:
# 'Pedestrian'
