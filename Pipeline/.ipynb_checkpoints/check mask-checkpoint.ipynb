# %%
import csv
import numpy as np
import os
import math
import threading
import Queue
import sys
import cv2
import base64
import elasticsearch

from data.bbox import Box
from collections import defaultdict
from collections import OrderedDict
from augmenter import *
from elasticsearch import Elasticsearch,client ,helpers

es = Elasticsearch()

# %%
from elasticsearch_dsl import Search

# %%
def get_scanners(slice_no):
    a = helpers.scan(es,index = 'open_image_train',
                doc_type = 'train',
                scroll = '2m',
                size = 1,
                query = {
                    'slice':{'id':slice_no,'max':SLICES},
                    'query':{'match_all':{}},
                    '_source':['xmin','ymin','xmax','ymax','mask']
                })
    return a

# %%
body = {
            'query':{'match_all':{}},
            '_source':['xmin','ymin','xmax','ymax','mask']
        }

# %%
s = Search.from_dict(body)

# %%
a = helpers.scan(es,index = 'open_image_train',
                doc_type = 'train',
                scroll = '2m',
                size = 1,
                query = {
#                     'slice':{'id':slice_no,'max':SLICES},
                    'query':{'match_all':{}},
                    '_source':['id ']
#                     '_source':['xmin','ymin','xmax','ymax','mask']
                },
                sort = ['_doc'])

# %%
from collections import defaultdict,OrderedDict
from data.bbox import Box
dict_annot = defaultdict(list)
filedir = '../../Dataset/OpenImage/'
annotations_file = filedir+'annotations/' + '{}-bbox.csv'.format('train')


with open(annotations_file,'r') as csvfile:
    with open('boxes.csv','w') as f:
        writer = csv.writer(f,delimiter=',')
        bbox_reader = csv.reader(csvfile,delimiter=',')
        print("Open Images contains a large number of files, do not be discourage if it takes a long time.")
        next(bbox_reader)
        dict_annot = defaultdict(list)
        pbar = tqdm(bbox_reader)
        pbar.set_description("Reading Annotations")
        labels = []
        names = []
        for j,elem in enumerate(pbar):
            filename = elem[0]
            label = elem[2]
            xmin = float(elem[4])
            xmax = float(elem[5])
            ymin = float(elem[6])
            ymax = float(elem[7])
            box = Box(x0=xmin, y0 = ymin, x1=xmax, y1=ymax,label=label)
            dict_annot[filename].append(box)
            if len(dict_annot) == 10 +1 :
                od = OrderedDict(dict_annot)
                temp2 = od.popitem()
                for filename in od.keys():
                    boxes = np.array(dict_annot[filename])
                    labels.append(boxes)
                    names.append(filename)
                for temp in _process_image_files(np.array(labels),names):
                    xmin ,ymin ,xmax ,ymax ,names = temp
                    hold_mask = np.zeros((800,800),dtype=np.uint8)
                    m_xmin = (np.array(xmin)*800)
                    m_xmax = (np.array(xmax)*800)
                    m_ymin = (np.array(ymin)*800)
                    m_ymax = (np.array(ymax)*800)
                    areas = np.trim_zeros((m_xmax - m_xmin) * (m_ymax - m_ymin))
                    sorted_inds = np.argsort(areas)

                    masks = np.zeros((800,800,len(sorted_inds)),dtype=np.uint8)
                    for i in sorted_inds:
                        b = int(np.floor(m_xmin[i]))
                        c = int(np.floor(m_xmax[i]))
                        d = int(np.floor(m_ymin[i]))
                        e = int(np.floor(m_ymax[i]))
                        masks[:,:,i] = hold_mask[:,:]
                        hold_mask[d:e,b:c] = 1
                    writer.writerow([names,hold_mask])
                labels = []
                names = []
                dict_annot.clear()
                dict_annot[temp2[0]] = temp2[1]
# Out:
# 0it [00:00, ?it/s]
#
#
#
#
#
#
#
#
#
# Reading Annotations: : 0it [00:00, ?it/s]
#
#
#
#
#
#
#
#
#
# Reading Annotations: : 138it [00:00, 1079.01it/s]
# Open Images contains a large number of files, do not be discourage if it takes a long time.
# Reading Annotations: : 346it [00:00, 458.41it/s]
#
#
#
#
#
#
#
#
#
# Reading Annotations: : 562it [00:00, 622.32it/s]
#
#
#
#
#
#
#
#
#
# Reading Annotations: : 773it [00:01, 734.51it/s]
#
#
#
#
#
#
#
#
#
# Reading Annotations: : 906it [00:01, 741.66it/s]
#
#
#
#
#
#
#
#
#
# Reading Annotations: : 1088it [00:01, 816.17it/s]
#
#
#
#
#
#
#
#
#
# Reading Annotations: : 1306it [00:01, 859.74it/s]
#
#
#
#
#
#
#
#
#
# Reading Annotations: : 1473it [00:01, 900.58it/s]
#
#
#
#
#
#
#
#
#
# Reading Annotations: : 1595it [00:01, 903.10it/s]
#
#
#
#
#
#
#
#
#
# Reading Annotations: : 1764it [00:01, 922.84it/s]
#
#
#
#
#
#
#
#
#
# Reading Annotations: : 1884it [00:02, 749.71it/s]
#
#
#
#
#
#
#
#
#
# Reading Annotations: : 2167it [00:02, 818.27it/s]
#
#
#
#
#
#
#
#
#
# Reading Annotations: : 2315it [00:02, 827.16it/s]
#
#
#
#
#
#
#
#
#
# Reading Annotations: : 2447it [00:02, 831.00it/s]
#
#
#
#
#
#
#
#
#
# Reading Annotations: : 2662it [00:03, 802.41it/s]
#
#
#
#
#
#
#
#
#
# Reading Annotations: : 2968it [00:03, 868.45it/s]
#
#
#
#
#
#
#
#
#
# Reading Annotations: : 3125it [00:03, 862.85it/s]
#
#
#
#
#
#
#
#
#
# Reading Annotations: : 3258it [00:04, 789.03it/s]
#
#
#
#
#
#
#
#
#
# Reading Annotations: : 3433it [00:04, 791.40it/s]
#
#
#
#
#
#
#
#
#
# Reading Annotations: : 3666it [00:04, 823.52it/s]
#
#
#
#
#
#
#
#
#
# Reading Annotations: : 3889it [00:04, 849.36it/s]
#
#
#
#
#
#
#
#
#
# Reading Annotations: : 4032it [00:04, 841.64it/s]
#
#
#
#
#
#
#
#
#
# Reading Annotations: : 4296it [00:05, 718.15it/s]
#
#
#
#
#
#
#
#
#
# Reading Annotations: : 4478it [00:06, 646.00it/s]
#
#
#
#
#
#
#
#
#
# Reading Annotations: : 4591it [00:07, 621.55it/s]
#
#
#
#
#
#
#
#
#
# Reading Annotations: : 4757it [00:07, 623.46it/s]
#
#
#
#
#
#
#
#
#
# Reading Annotations: : 5003it [00:07, 641.42it/s]
#
#
#
#
#
#
#
#
#
# Reading Annotations: : 5249it [00:07, 659.57it/s]
#
#
#
#
#
#
#
#
#
# Reading Annotations: : 5483it [00:08, 678.42it/s]
#
#
#
#
#
#
#
#
#
# Reading Annotations: : 5786it [00:08, 704.87it/s]
#
#
#
#
#
#
#
#
#
# Reading Annotations: : 5950it [00:08, 715.94it/s]
#
#
#
#
#
#
#
#
#
# Reading Annotations: : 6113it [00:08, 725.30it/s]
#
#
#
#
#
#
#
#
#
# Reading Annotations: : 6269it [00:08, 714.74it/s]
#
#
#
#
#
#
#
#
#
# Reading Annotations: : 6392it [00:09, 693.92it/s]
#
#
#
#
#
#
#
#
#
# Reading Annotations: : 6552it [00:09, 693.66it/s]
#
#
#
#
#
#
#
#
#
# Reading Annotations: : 6899it [00:10, 668.08it/s]
#
#
#
#
#
#
#
#
#
# Reading Annotations: : 7067it [00:10, 676.00it/s]
#
#
#
#
#
#
#
#
#
# Reading Annotations: : 7180it [00:10, 679.89it/s]
#
#
#
#
#
#
#
#
#
# Reading Annotations: : 7378it [00:10, 690.59it/s]
#
#
#
#
#
#
#
#
#
# Reading Annotations: : 7592it [00:11, 686.36it/s]
#
#
#
#
#
#
#
#
#
# Reading Annotations: : 7788it [00:11, 696.21it/s]
#
#
#
#
#
#
#
#
#
# Reading Annotations: : 7955it [00:11, 702.38it/s]
#
#
#
#
#
#
#
#
#
# Reading Annotations: : 8203it [00:11, 717.95it/s]
#
#
#
#
#
#
#
#
#
# Reading Annotations: : 8359it [00:11, 714.07it/s]
#
#
#
#
#
#
#
#
#
# Reading Annotations: : 8490it [00:11, 716.58it/s]
#
#
#
#
#
#
#
#
#
# Reading Annotations: : 8765it [00:12, 725.75it/s]
#
#
#
#
#
#
#
#
#
# Reading Annotations: : 8979it [00:12, 736.46it/s]
#
#
#
#
#
#
#
#
#
# Reading Annotations: : 9217it [00:12, 747.04it/s]
#
#
#
#
#
#
#
#
#
# Reading Annotations: : 9402it [00:12, 754.68it/s]
#
#
#
#
#
#
#
#
#
# Reading Annotations: : 9703it [00:13, 745.30it/s]
#
#
#
#
#
#
#
#
#
# Reading Annotations: : 9863it [00:13, 740.16it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-64-a3c93b9b91e6> in <module>()
#      51                         d = int(np.floor(m_ymin[i]))
#      52                         e = int(np.floor(m_ymax[i]))
# ---> 53                         masks[:,:,i] = hold_mask[:,:]
#      54                         hold_mask[d:e,b:c] = 1
#      55                     writer.writerow([names,hold_mask])
#
# KeyboardInterrupt:

# %%
def _process_image_files(labels,names):
    for index in range(labels.shape[0]):
        height = float(800)
        width = float(800)
        xmin = []
        xmax = []
        ymin = []
        ymax = []
        label = []
        #get the xyxy components of box
        boxes = labels[index]
        for i in boxes:
            b = i.xyxy
            xmin.append(b[0]/width)
            ymin.append(b[1]/height)
            xmax.append(b[2]/width)
            ymax.append(b[3]/height)
            label.append(box.label)

        yield xmin ,ymin ,xmax ,ymax,names[index]

# %%
labels = np.array(labels)

# %%
labels.shape[0]
# Out:
# 10

# %%
a = labels[2][0]

# %%
a.xyxy
# Out:
# [0.0, 0.278703, 0.83, 0.927257]

# %%
page = es.search(
        index = 'open_image_train',
        doc_type = 'train',
        scroll = '2m',
        size = 1,
        body = {
            'query':{'match_all':{}},
            '_source':['xmin','ymin','xmax','ymax','mask']
        },
        request_timeout = 1000
    )
sid = page['_scroll_id']
scroll_size = page['hits']['total']

# Start scrolling
for i in tqdm(range(1724429)):
    page = es.scroll(scroll_id = sid, scroll = '2m',request_timeout = 100)
    # Update the scroll ID
    sid = page['_scroll_id']
    # Get the number of results that we returned in the last scroll
    scroll_size = len(page['hits']['hits'])
    for j in page['hits']['hits']:
        iden = j['_id']
        xmin = j['_source']['xmin']
        xmax = j['_source']['xmax']
        ymin = j['_source']['ymin']
        ymax = j['_source']['ymax']
        mask = j['_source']['mask']
        hold_mask = np.zeros((800,800),dtype=np.uint8)
        m_xmin = (np.array(xmin)*800)
        m_xmax = (np.array(xmax)*800)
        m_ymin = (np.array(ymin)*800)
        m_ymax = (np.array(ymax)*800)
        areas = np.trim_zeros((m_xmax - m_xmin) * (m_ymax - m_ymin))
        sorted_inds = np.argsort(areas)

        masks = np.zeros((800,800,len(sorted_inds)),dtype=np.uint8)
        for i in sorted_inds:
            b = int(np.floor(m_xmin[i]))
            c = int(np.floor(m_xmax[i]))
            d = int(np.floor(m_ymin[i]))
            e = int(np.floor(m_ymax[i]))
            masks[:,:,i] = hold_mask[:,:]
            hold_mask[d:e,b:c] = 1
        
    check = str(base64.b64encode(masks.tobytes()))
    if not (mask == check):
        print i
        print iden
        break
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-17-5508dde8cbe2> in <module>()
#      15 # Start scrolling
#      16 for i in range(1724429):
# ---> 17     page = es.scroll(scroll_id = sid, scroll = '2m',request_timeout = 100)
#      18     # Update the scroll ID
#      19     sid = page['_scroll_id']
#
# /usr/local/lib/python2.7/dist-packages/elasticsearch/client/utils.pyc in _wrapped(*args, **kwargs)
#      74                 if p in kwargs:
#      75                     params[p] = kwargs.pop(p)
# ---> 76             return func(*args, params=params, **kwargs)
#      77         return _wrapped
#      78     return _wrapper
#
# /usr/local/lib/python2.7/dist-packages/elasticsearch/client/__init__.pyc in scroll(self, scroll_id, body, params)
#    1009
#    1010         return self.transport.perform_request('GET', '/_search/scroll',
# -> 1011             params=params, body=body)
#    1012
#    1013     @query_params()
#
# /usr/local/lib/python2.7/dist-packages/elasticsearch/transport.pyc in perform_request(self, method, url, headers, params, body)
#     316                 delay = 2**attempt - 1
#     317                 time.sleep(delay)
# --> 318                 status, headers_response, data = connection.perform_request(method, url, params, body, headers=headers, ignore=ignore, timeout=timeout)
#     319
#     320             except TransportError as e:
#
# /usr/local/lib/python2.7/dist-packages/elasticsearch/connection/http_urllib3.pyc in perform_request(self, method, url, params, body, timeout, ignore, headers)
#     169                     body = gzip.zlib.compress(body)
#     170
# --> 171             response = self.pool.urlopen(method, url, body, retries=False, headers=request_headers, **kw)
#     172             duration = time.time() - start
#     173             raw_data = response.data.decode('utf-8')
#
# /usr/local/lib/python2.7/dist-packages/urllib3/connectionpool.pyc in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     598                                                   timeout=timeout_obj,
#     599                                                   body=body, headers=headers,
# --> 600                                                   chunked=chunked)
#     601
#     602             # If we're going to release the connection in ``finally:``, then
#
# /usr/local/lib/python2.7/dist-packages/urllib3/connectionpool.pyc in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     375         try:
#     376             try:  # Python 2.7, use buffering of HTTP responses
# --> 377                 httplib_response = conn.getresponse(buffering=True)
#     378             except TypeError:  # Python 2.6 and older, Python 3
#     379                 try:
#
# /usr/lib/python2.7/httplib.pyc in getresponse(self, buffering)
#    1134
#    1135         try:
# -> 1136             response.begin()
#    1137             assert response.will_close != _UNKNOWN
#    1138             self.__state = _CS_IDLE
#
# /usr/lib/python2.7/httplib.pyc in begin(self)
#     451         # read until we get a non-100 response
#     452         while True:
# --> 453             version, status, reason = self._read_status()
#     454             if status != CONTINUE:
#     455                 break
#
# /usr/lib/python2.7/httplib.pyc in _read_status(self)
#     407     def _read_status(self):
#     408         # Initialize with Simple-Response defaults
# --> 409         line = self.fp.readline(_MAXLINE + 1)
#     410         if len(line) > _MAXLINE:
#     411             raise LineTooLong("header line")
#
# /usr/lib/python2.7/socket.pyc in readline(self, size)
#     478             while True:
#     479                 try:
# --> 480                     data = self._sock.recv(self._rbufsize)
#     481                 except error, e:
#     482                     if e.args[0] == EINTR:
#
# KeyboardInterrupt:

# %%
check = str(base64.b64encode(masks.tobytes()))

# %%
mask == check
# Out:
# True

# %%
work = Queue.Queue(maxsize=1000)

def do_work(in_queue):
    while True:
        iden,xmin,xmax,ymin,ymax = in_queue.get()

        hold_mask = np.zeros((800,800),dtype=np.uint8)
        m_xmin = (np.array(xmin)*800)
        m_xmax = (np.array(xmax)*800)
        m_ymin = (np.array(ymin)*800)
        m_ymax = (np.array(ymax)*800)
        areas = np.trim_zeros((m_xmax - m_xmin) * (m_ymax - m_ymin))
        sorted_inds = np.argsort(areas)

        masks = np.zeros((800,800,len(sorted_inds)),dtype=np.uint8)
        for i in sorted_inds:
            b = int(np.floor(m_xmin[i]))
            c = int(np.floor(m_xmax[i]))
            d = int(np.floor(m_ymin[i]))
            e = int(np.floor(m_ymax[i]))
            masks[:,:,i] = hold_mask[:,:]
            hold_mask[d:e,b:c] = 1
        try:
            es.update(index = 'open_image_train',doc_type = 'train',id=iden,
            body={'doc':{'mask':str(base64.b64encode(masks.tobytes()))}},retry_on_conflict = 100000)
    except:
        with open('logs.txt','a') as f:
        writer = csv.writer(f)
        writer.writerow(iden)
    in_queue.task_done()

for i in xrange(40):
    t = threading.Thread(target=do_work,args=(work,))
    t.daemon = True
    t.start()


page = es.search(
        index = 'open_image_train',
        doc_type = 'train',
        scroll = '2m',
        size = 1,
        body = {
            'query':{'match_all':{}},
            '_source':['xmin','ymin','xmax','ymax']
        },
        request_timeout = 1000
    )
sid = page['_scroll_id']
scroll_size = page['hits']['total']

# Start scrolling
for i in tqdm(range(1724429)):
    page = es.scroll(scroll_id = sid, scroll = '2m',request_timeout = 100)
    # Update the scroll ID
    sid = page['_scroll_id']
    # Get the number of results that we returned in the last scroll
    scroll_size = len(page['hits']['hits'])
    for j in page['hits']['hits']:
        iden = j['_id']
        xmin = j['_source']['xmin']
        xmax = j['_source']['xmax']
        ymin = j['_source']['ymin']
        ymax = j['_source']['ymax']
        action = (iden,xmin,xmax,ymin,ymax)
        work.put(action)
